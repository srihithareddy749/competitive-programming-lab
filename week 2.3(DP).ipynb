# %% [markdown]
# <a href="https://colab.research.google.com/github/srihithareddy749/competitive-programming-lab/blob/main/week%202.3(DP).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fibonacci(n, dp):
    if n <= 1:
        return n

    if dp[n] != -1:
        return dp[n]

    dp[n] = fibonacci(n - 1, dp) + fibonacci(n - 2, dp)
    return dp[n]


# Input
n = int(input())

# Initialize memoization array
dp = [-1] * (n + 1)

# Output
print(fibonacci(n, dp))
# Out:
# 10
# 55
